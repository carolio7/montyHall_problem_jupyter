# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from random import randint, seed

from fonctionsMontyHall_numpy import monty_hall, Strategie

# %%
print("En changeant de porte, le joueur a gagné {} sur 10000 parties".format(sum(monty_hall("CHANGER",10000))))

print("En gardant de porte, le joueur a gagné {} sur 10000 parties".format(sum(monty_hall("GARDER", 10000))))
# Out:
# En changeant de porte, le joueur a gagné 6669 sur 10000 parties
# En gardant de porte, le joueur a gagné 3236 sur 10000 parties

# %%
plot = plt.plot(monty_hall("CHANGER",10))

# %%
plot = plt.plot(monty_hall("CHANGER", 10000))

# %%
plot = plt.scatter(range(10000), monty_hall("CHANGER",10000))

# %%
plot = plt.bar([1,2],[sum(monty_hall("CHANGER",10000)),
                     sum(monty_hall("GARDER", 10000))],
              tick_label=["Changer","Garder"])

# %%
# Evolution des gains des joueurs en fontion du nombre de parties
gains_changer = []
gains_garder = []
samples = [1000, 10000, 20000, 50000, 80000, 100000]
for tours in samples:
    gains_changer.append(monty_hall("CHANGER", tours))
    gains_garder.append(monty_hall("GARDER", tours))

# %%
figure = plt.figure()
plot = plt.scatter(samples, [sum(x) for x in gains_changer])
plot = plt.scatter(samples, [sum(x) for x in gains_garder])
